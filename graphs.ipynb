# %%
import pandas as pd
  
# Create a list of data to be represented in x-axis
vus = [ 10 , 25 , 50 ,
        100 , 200 , 300, 400 ]
  
# Using the avg values for duration_trends and calculating the average of 3 runs

# edit-book-10 - 9.904242, 9.074505, 11.989492 = 10.3227463
# get-book-10 - 7.849398, 7.50637, 9.421284 = 8.25901733
# login-10 - 43.762002, 48.465752, 52.763033 = 48.3302623

# edit-book-25 - 6.093018, 13.923673, 9.257459 = 9.75805
# get-book-25 - 4.430784, 11.340597, 7.154743 = 7.6420413333333
# login-25 - 52.092162, 110.908086, 73.327073 = 78.775773666667

# edit-book-50 - 13.068437, 6.218791, 16.215985 = 	11.834404333333
# get-book-50 - 12.277769, 9.546766, 4.516968 = 8.780501
# login-50 - 1158.762252, 1096.793459, 1185.952229 = 1147.1693133333

# edit-book-100 - 23.686835, 17.966221, 6.242317 = 15.965124333333
# get-book-100 - 18.512631, 11.690881, 4.868044 = 11.690518666667
# login-100 - 2967.007483, 5463.063956, 5384.671365 = 	4604.914268

# edit-book-200 - 10.970122, 75.055125, 74.152644 = 53.392630333333
# get-book-200 - 68.220307, 68.624892, 8.696728 = 48.513975666667
# login-200 - 14191.544717, 14367.79715, 8901.393943 = 12486.911936667

# edit-book-300 - 147.467085, 180.74711, 153.052469 = 160.42222133333
# get-book-300 - 145.292869, 176.765405, 155.101115 = 159.05312966667
# login-300 - 20670.7193, 21161.968497, 21412.148381 = 21081.612059333

# edit-book-400 - 382.097868, 751.512737, 240.603412 = 458.071339
# get-book-400 - 233.199216, 719.51273, 351.948213 = 434.88671966667
# login-400 - 29670.155779, 28737.885201, 26714.997696 = 28374.346225333

edit_book_response_times = [ 10.3227463 , 9.75805 , 11.834404333333 , 15.965124333333 ,
            53.392630333333 , 160.42222133333 , 458.071339 ]

get_book_response_times = [ 8.25901733 , 7.6420413333333 , 8.780501 , 11.690518666667 , 
            48.513975666667 , 159.05312966667 , 434.88671966667 ]

login_response_times = [ 48.3302623 , 78.775773666667 , 1147.1693133333 , 4604.914268 ,
            12486.911936667 , 21081.612059333 , 28374.346225333 ]


edit_book_min_response_times = [ 4.839180666666667 , 4.639180333333333 , 5.050055666666666 ,  4.605042 , 
                                4.608069333333333, 5.259, 5.435569666666666]

get_book_min_response_times = [ 3.2414443333333334,  3.0738193333333332, 3.5795, 3.2509029999999997, 
                               3.330875333333333, 3.6855553333333333, 3.824514]

login_response_min_times = [ 5.519694666666666,  5.757472333333333, 197.71324966666666, 130.77713866666667, 
                            234.39934733333334, 260.05354166666666, 460.81326400000006]









edit_book_max_response_times = [ 50.634666333333335 , 131.96483333333333, 229.31715266666666, 607.224625, 966.222875, 3785.549043333334, 7139.138596 ]

get_book_max_response_times = [ 59.74925033333333, 128.48752766666667, 238.0698196666667, 446.7851943333333, 951.1402086666667, 3762.197904666666, 6964.458887666667  ]

login_response_max_times = [ 181.30258333333336, 397.260028, 2290.9168203333334, 6030.577372666667, 15128.756419333333, 26652.208025999997, 37341.195156 ]



edit_book_med_response_times = [ 8.550076666666667, 7.970326666666668, 10.785729666666667, 8.705097666666667, 10.011181, 12.690736333333334, 14.433104666666665 ]

get_book_med_response_times = [ 6.445153, 5.781597333333333, 7.845333, 6.374291333333333, 7.380201333333333, 9.551125333333333, 10.848083333333333  ]

login_response_med_times = [ 40.746729, 47.401771000000004, 1117.370776, 4686.911580666667, 13326.776746666668, 23405.897239666665, 31744.539792333333  ]


edit_book_p90_response_times = [17.733410000000003, 12.486838999999998, 19.496583333333334, 17.740920666666668, 102.44755266666668, 323.4404336666667, 831.6215976666666  ]

get_book_p90_response_times = [ 14.930909666666665, 10.107431, 14.123212333333333, 12.758345666666665, 76.91044166666667, 260.5656463333333, 767.600367 ]

login_response_p90_times = [ 71.73132633333334, 165.432739, 1521.2120946666666, 5286.758903999999, 14354.573856666668, 25435.246223666665, 35892.780292 ]



edit_book_p95_response_times = [20.703688, 15.447858333333334, 26.98645666666667, 29.630818333333334, 309.73318466666666, 984.260753, 3926.687086 ]

get_book_p95_response_times = [ 17.416185, 14.840086999999999, 19.091637333333335, 21.287464666666665, 283.00773566666663, 908.6576106666666, 3872.78829 ]

login_response_p95_times = [ 89.737662, 216.82276866666666, 1708.815555, 5653.337697333333, 14687.072523666668, 25881.462687333333, 36380.07779533334 ]
  
# Create a dataframe using the two lists
df_edit_times = pd.DataFrame(
    { 'vu' : vus , 'edit_response_time' : edit_book_response_times })

df_get_times = pd.DataFrame(
    { 'vu' : vus , 'get_response_time' : get_book_response_times })

df_login_times = pd.DataFrame(
    { 'vu' : vus , 'login_response_time' : login_response_times })



# Create a dataframe using the two lists
df_edit_min_times = pd.DataFrame(
    { 'vu' : vus , 'edit_min_response_time' : edit_book_min_response_times })

df_get_min_times = pd.DataFrame(
    { 'vu' : vus , 'get_min_response_time' : get_book_min_response_times })

df_login_min_times = pd.DataFrame(
    { 'vu' : vus , 'login_min_response_time' : login_response_min_times })

# Create a dataframe using the two lists
df_edit_max_times = pd.DataFrame(
    { 'vu' : vus , 'edit_max_response_time' : edit_book_max_response_times })

df_get_max_times = pd.DataFrame(
    { 'vu' : vus , 'get_max_response_time' : get_book_max_response_times })

df_login_max_times = pd.DataFrame(
    { 'vu' : vus , 'login_max_response_time' : login_response_max_times })


# Create a dataframe using the two lists
df_edit_med_times = pd.DataFrame(
    { 'vu' : vus , 'edit_med_response_time' : edit_book_med_response_times })

df_get_med_times = pd.DataFrame(
    { 'vu' : vus , 'get_med_response_time' : get_book_med_response_times })

df_login_med_times = pd.DataFrame(
    { 'vu' : vus , 'login_med_response_time' : login_response_med_times })

# Create a dataframe using the two lists
df_edit_p90_times = pd.DataFrame(
    { 'vu' : vus , 'edit_p90_response_time' : edit_book_p90_response_times })

df_get_p90_times = pd.DataFrame(
    { 'vu' : vus , 'get_p90_response_time' : get_book_p90_response_times })

df_login_p90_times = pd.DataFrame(
    { 'vu' : vus , 'login_p90_response_time' : login_response_p90_times })

# Create a dataframe using the two lists
df_edit_p95_times = pd.DataFrame(
    { 'vu' : vus , 'edit_p95_response_time' : edit_book_p95_response_times })

df_get_p95_times = pd.DataFrame(
    { 'vu' : vus , 'get_p95_response_time' : get_book_p95_response_times })

df_login_p95_times = pd.DataFrame(
    { 'vu' : vus , 'login_p95_response_time' : login_response_p95_times })





# use plot() method on the dataframe
ep = df_edit_times.plot( 'vu' , 'edit_response_time' )
ep.set_ylabel('average response time (ms)')
ep.set_xlabel('number of concurrent sessions (vus)')
gp = df_get_times.plot( 'vu' , 'get_response_time' )
gp.set_ylabel('average response time (ms)')
gp.set_xlabel('number of concurrent sessions (vus)')
lp = df_login_times.plot( 'vu' , 'login_response_time' )
lp.set_ylabel('average response time (ms)')
lp.set_xlabel('number of concurrent sessions (vus)')



# use plot() method on the dataframe
ep = df_edit_min_times.plot( 'vu' , 'edit_min_response_time' )
ep.set_ylabel('min response time (ms)')
ep.set_xlabel('number of concurrent sessions (vus)')
gp = df_get_min_times.plot( 'vu' , 'get_min_response_time' )
gp.set_ylabel('min response time (ms)')
gp.set_xlabel('number of concurrent sessions (vus)')
lp = df_login_min_times.plot( 'vu' , 'login_min_response_time' )
lp.set_ylabel('min response time (ms)')
lp.set_xlabel('number of concurrent sessions (vus)')


# use plot() method on the dataframe
ep = df_edit_max_times.plot( 'vu' , 'edit_max_response_time' )
ep.set_ylabel('max response time (ms)')
ep.set_xlabel('number of concurrent sessions (vus)')
gp = df_get_max_times.plot( 'vu' , 'get_max_response_time' )
gp.set_ylabel('max response time (ms)')
gp.set_xlabel('number of concurrent sessions (vus)')
lp = df_login_max_times.plot( 'vu' , 'login_max_response_time' )
lp.set_ylabel('max response time (ms)')
lp.set_xlabel('number of concurrent sessions (vus)')


# use plot() method on the dataframe
ep = df_edit_med_times.plot( 'vu' , 'edit_med_response_time' )
ep.set_ylabel('med response time (ms)')
ep.set_xlabel('number of concurrent sessions (vus)')
gp = df_get_med_times.plot( 'vu' , 'get_med_response_time' )
gp.set_ylabel('med response time (ms)')
gp.set_xlabel('number of concurrent sessions (vus)')
lp = df_login_med_times.plot( 'vu' , 'login_med_response_time' )
lp.set_ylabel('med response time (ms)')
lp.set_xlabel('number of concurrent sessions (vus)')


# use plot() method on the dataframe
ep = df_edit_p90_times.plot( 'vu' , 'edit_p90_response_time' )
ep.set_ylabel('p90 response time (ms)')
ep.set_xlabel('number of concurrent sessions (vus)')
gp = df_get_p90_times.plot( 'vu' , 'get_p90_response_time' )
gp.set_ylabel('p90 response time (ms)')
gp.set_xlabel('number of concurrent sessions (vus)')
lp = df_login_p90_times.plot( 'vu' , 'login_p90_response_time' )
lp.set_ylabel('p90 response time (ms)')
lp.set_xlabel('number of concurrent sessions (vus)')


# use plot() method on the dataframe
ep = df_edit_p95_times.plot( 'vu' , 'edit_p95_response_time' )
ep.set_ylabel('p95 response time (ms)')
ep.set_xlabel('number of concurrent sessions (vus)')
gp = df_get_p95_times.plot( 'vu' , 'get_p95_response_time' )
gp.set_ylabel('p95 response time (ms)')
gp.set_xlabel('number of concurrent sessions (vus)')
lp = df_login_p95_times.plot( 'vu' , 'login_p95_response_time' )
lp.set_ylabel('p95 response time (ms)')
lp.set_xlabel('number of concurrent sessions (vus)')
# Out:
# Text(0.5, 0, 'number of concurrent sessions (vus)')
